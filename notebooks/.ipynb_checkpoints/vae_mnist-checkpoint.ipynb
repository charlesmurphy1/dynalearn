# %% [markdown]
# # Testing the VAE on MNIST dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader
from dynalearn.datasets.mnist_dataset import load_MNIST, one_hot_to_int
from dynalearn.models.vae import VAE,FC_VAE

def display_number(imag, ax):
    ax.imshow(imag, cmap="gray")
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.get_xaxis().set_ticklabels([])
    ax.get_yaxis().set_ticklabels([])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)

# %%
mnist_train, mnist_test = load_MNIST("./data/mnist", vectorize=True, target_onehot=True, num_train=60000,
                                     num_val=1000)

vae = FC_VAE(28 * 28, [512, 256, 128], 2, keepprob=0.99,
             optimizer=lambda p: torch.optim.Adam(p, lr=1e-3, weight_decay=0))
print(vae)
# Out:
# VAE(
#   (encoder): Fc_Encoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.010000000000000009)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.010000000000000009)
#       (6): Linear(in_features=256, out_features=128, bias=True)
#       (7): Tanh()
#       (8): Dropout(p=0.010000000000000009)
#     )
#     (mu): Linear(in_features=128, out_features=2, bias=True)
#     (var): Linear(in_features=128, out_features=2, bias=True)
#   )
#   (decoder): Fc_Decoder(
#     (decoder): Sequential(
#       (0): Linear(in_features=2, out_features=128, bias=True)
#       (1): Tanh()
#       (2): Dropout(p=0.010000000000000009)
#       (3): Linear(in_features=128, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.010000000000000009)
#       (6): Linear(in_features=256, out_features=512, bias=True)
#       (7): ReLU()
#       (8): Dropout(p=0.010000000000000009)
#       (9): Linear(in_features=512, out_features=784, bias=True)
#       (10): Sigmoid()
#     )
#   )
#   (loss): BCELoss()
# )

# %% [markdown]
# ## Training the vae

# %%
vae.fit(mnist_train, mnist_test, epochs=50, batch_size=128, verbose=True, keep_best=True)
# Out:
# /home/charles/anaconda3/lib/python3.6/site-packages/torch/tensor.py:287: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
# Epoch 0 - Train loss: 160.4736 - Val loss: 158.6731 - Training time: 31.4878 - New best config.
# Epoch 1 - Train loss: 151.8015 - Val loss: 151.0110 - Training time: 37.8443 - New best config.
# Epoch 2 - Train loss: 148.6279 - Val loss: 148.3099 - Training time: 36.5550 - New best config.
# Epoch 3 - Train loss: 146.9776 - Val loss: 146.5946 - Training time: 37.3826 - New best config.
# Epoch 4 - Train loss: 145.5556 - Val loss: 145.0776 - Training time: 38.8663 - New best config.
# Epoch 5 - Train loss: 145.1104 - Val loss: 144.3725 - Training time: 39.3104 - New best config.
# Epoch 6 - Train loss: 144.1987 - Val loss: 143.7539 - Training time: 39.4004 - New best config.
# Epoch 7 - Train loss: 143.3292 - Val loss: 143.0610 - Training time: 38.8895 - New best config.
# Epoch 8 - Train loss: 143.2197 - Val loss: 142.8178 - Training time: 39.2841 - New best config.
# Epoch 9 - Train loss: 142.0202 - Val loss: 141.3725 - Training time: 38.8957 - New best config.
# Epoch 10 - Train loss: 141.8626 - Val loss: 141.1790 - Training time: 38.5463 - New best config.
# Epoch 11 - Train loss: 140.9020 - Val loss: 141.1251 - Training time: 38.8276 - New best config.
# Epoch 12 - Train loss: 141.0862 - Val loss: 141.0613 - Training time: 38.9322 - New best config.
# Epoch 13 - Train loss: 140.2870 - Val loss: 139.9851 - Training time: 38.5325 - New best config.
# Epoch 14 - Train loss: 139.6159 - Val loss: 140.3256 - Training time: 39.0483
# Epoch 15 - Train loss: 139.8196 - Val loss: 140.5542 - Training time: 39.0198
# Epoch 16 - Train loss: 139.4175 - Val loss: 138.9670 - Training time: 39.2949 - New best config.
# Epoch 17 - Train loss: 138.7825 - Val loss: 138.5461 - Training time: 39.8373 - New best config.
# Epoch 18 - Train loss: 138.1713 - Val loss: 137.9704 - Training time: 39.7483 - New best config.
# Epoch 19 - Train loss: 138.1261 - Val loss: 137.7709 - Training time: 39.8539 - New best config.
# Epoch 20 - Train loss: 138.0096 - Val loss: 137.9111 - Training time: 40.3265
# Epoch 21 - Train loss: 138.4161 - Val loss: 137.7255 - Training time: 39.7515 - New best config.
# Epoch 22 - Train loss: 137.9477 - Val loss: 137.5631 - Training time: 41.1866 - New best config.
# Epoch 23 - Train loss: 137.5412 - Val loss: 137.3109 - Training time: 43.4575 - New best config.
# Epoch 24 - Train loss: 137.5090 - Val loss: 136.9513 - Training time: 41.3714 - New best config.
# Epoch 25 - Train loss: 137.0131 - Val loss: 136.1661 - Training time: 41.4528 - New best config.
# Epoch 26 - Train loss: 137.7139 - Val loss: 136.9637 - Training time: 42.0484
# Epoch 27 - Train loss: 137.1391 - Val loss: 137.2397 - Training time: 41.7223
# Epoch 28 - Train loss: 136.8467 - Val loss: 136.5864 - Training time: 41.2931
# Epoch 29 - Train loss: 136.7565 - Val loss: 136.3959 - Training time: 41.5805
# Epoch 30 - Train loss: 136.9046 - Val loss: 137.3765 - Training time: 41.7478
# Epoch 31 - Train loss: 137.7673 - Val loss: 138.0460 - Training time: 41.7615
# Epoch 32 - Train loss: 136.9397 - Val loss: 136.7406 - Training time: 42.3559
# Epoch 33 - Train loss: 136.7001 - Val loss: 136.0018 - Training time: 42.7658 - New best config.
# Epoch 34 - Train loss: 136.2712 - Val loss: 136.4334 - Training time: 44.8622
# Epoch 35 - Train loss: 136.3241 - Val loss: 136.7430 - Training time: 52.1731
# Epoch 36 - Train loss: 136.2746 - Val loss: 136.1291 - Training time: 53.0180
# Epoch 37 - Train loss: 136.1390 - Val loss: 136.2132 - Training time: 51.7997
# Epoch 38 - Train loss: 136.2549 - Val loss: 136.2699 - Training time: 51.3303
# Epoch 39 - Train loss: 135.5639 - Val loss: 136.2414 - Training time: 61.9527
# Epoch 40 - Train loss: 136.7443 - Val loss: 136.0379 - Training time: 53.8286
# Epoch 41 - Train loss: 136.0157 - Val loss: 135.3872 - Training time: 54.1690 - New best config.
# Epoch 42 - Train loss: 135.4797 - Val loss: 135.8646 - Training time: 52.4525
# Epoch 43 - Train loss: 135.3523 - Val loss: 135.3900 - Training time: 52.7659
# Epoch 44 - Train loss: 135.5651 - Val loss: 135.5752 - Training time: 53.0540
# Epoch 45 - Train loss: 135.5911 - Val loss: 135.5167 - Training time: 53.8392
# Epoch 46 - Train loss: 135.5058 - Val loss: 135.4245 - Training time: 47.3894
# Epoch 47 - Train loss: 135.1351 - Val loss: 135.2726 - Training time: 49.1608 - New best config.
# Epoch 48 - Train loss: 135.2007 - Val loss: 135.6757 - Training time: 48.0194
# Epoch 49 - Train loss: 135.7151 - Val loss: 135.2988 - Training time: 47.3852

# %% [markdown]
# ## Displaying samples for the model

# %%
N = 20
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
z = np.linspace(-4, 4, N)


img = np.zeros([N*28, N*28])
for k in range(N * N):
    i, j = k // N, k % N
    
    embedding = torch.tensor([z[i], z[j]])
    x = vae.decoder(embedding).detach().cpu().numpy()
    x = x.reshape(28, 28)
    
    img[28 * i : 28 * (i + 1), 28 * j : 28 * (j + 1)] = x
            
display_number(img, ax)
ax.set_aspect('equal')
fig.savefig('fig/sample_in_embedding.png')
plt.show()
# Out:
# (560, 560)

# %% [markdown]
# ## Showing embedding of each test sample

# %%
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

def get_embeddings(model, dataset):
    
    embeddings = []
    for x, label in dataset:
        c = one_hot_to_int(label, 10)
        mu, logvar = vae.encoder(x)
        mu = mu.detach().cpu().numpy()
        data = np.concatenate([mu, np.array([c])])
        embeddings.append(data)
    
    return np.array(embeddings)

embeddings = get_embeddings(vae, mnist_train)
# Out:
# /home/charles/anaconda3/lib/python3.6/site-packages/torch/tensor.py:287: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")

# %%
color = discrete_cmap(10, 'jet')
fig, ax = plt.subplots(1, 1, figsize=(12,8))

c_ = [color(int(i)) for i in embeddings[:, 2]]

sc = ax.scatter(embeddings[:,0], embeddings[:,1], c=embeddings[:, 2], marker='.',
                 edgecolor='none', cmap=discrete_cmap(10, 'jet'))

ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.set_aspect('equal')
plt.colorbar(sc)

plt.show()
#print(color(2.))
